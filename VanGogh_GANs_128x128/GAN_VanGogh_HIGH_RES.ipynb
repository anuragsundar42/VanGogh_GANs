# %% [markdown]
# # 1. Import Dependencies and Data

# %%
#!pip install tensorflow tensorflow-gpu matplotlib tensorflow-datasets ipywidgets

# %%
#!pip list

# %%
# Bringing in tensorflow
# import tensorflow as tf
# gpus = tf.config.experimental.list_physical_devices('GPU')
# for gpu in gpus: 
#     tf.config.experimental.set_memory_growth(gpu, True)

# %%
import tensorflow as tf
# Brining in tensorflow datasets for fashion mnist 
import tensorflow_datasets as tfds
# Bringing in matplotlib for viz stuff
from matplotlib import pyplot as plt
from zipfile import ZipFile

# %%
# zf = ZipFile("Saint Remy.zip")
# zf.extractall(path = 'Saint_Remy/')
# zf.close()
# print("... done")

# %% [markdown]
# # 2. Viz Data and Build Dataset

# %%
# Do some data transformation
import numpy as np

# %%
import cv2
import os

# Specify the directory where your Van Gogh paintings are stored
data_dir = '/home/notebooks/sundar/Saint_Remy/Saint Remy'

# Create a list to store image file paths
image_paths = []

for filename in os.listdir(data_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_paths.append(os.path.join(data_dir, filename))

# %%
def preprocess_image(image):
    # Resize the image to your desired dimensions
    image = cv2.resize(image, (128, 128))
    
    # Normalize pixel values to the range [0, 1]
    image = image / 255.0

    return image

# %%
# Load and preprocess the images
images = []
for image_path in image_paths:
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB format
    image = preprocess_image(image)
    images.append(image)

# Convert the list of preprocessed images to a TensorFlow dataset
ds = tf.data.Dataset.from_tensor_slices(images)

# %%
ds = ds.cache()
ds = ds.shuffle(len(image_paths))  # Use the number of images as the buffer size
ds = ds.batch(32)
ds = ds.prefetch(64)

# %%
ds
# Out:
# <PrefetchDataset element_spec=TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float64, name=None)>

# %%
ds.as_numpy_iterator().next().shape
# Out:
# (32, 128, 128, 3)

# %%
# Extract one batch (one image)
batch = next(iter(ds.take(1)))

# Extract the image from the batch
first_image = batch[0]

# Display the image using Matplotlib
plt.imshow(first_image.numpy())
plt.axis('off')  # Turn off axis labels and ticks
plt.show()

# %% [markdown]
# # 3. Build Neural Network

# %% [markdown]
# ### 3.1 Import Modelling Components

# %%
# Bring in the sequential api for the generator and discriminator
from tensorflow.keras.models import Sequential
# Bring in the layers for the neural network
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Reshape, LeakyReLU, Dropout, UpSampling2D

# %% [markdown]
# ### 3.2 Build Generator

# %%
def build_generator():
    model = Sequential()

    # Input shape is modified to match the desired shape (512, 512, 3)
    model.add(Dense(32 * 32 * 256, input_dim=256))  # Assuming input_dim is 256
    model.add(LeakyReLU(0.2))
    model.add(Reshape((32, 32, 256)))

    # Upsampling block 1
    model.add(UpSampling2D())
    model.add(Conv2D(128, 5, padding='same'))
    model.add(LeakyReLU(0.2))

    # Upsampling block 2
    model.add(UpSampling2D())
    model.add(Conv2D(128, 5, padding='same'))
    model.add(LeakyReLU(0.2))

    # Convolutional block 1
    model.add(Conv2D(64, 4, padding='same'))
    model.add(LeakyReLU(0.2))

    # Convolutional block 2
    model.add(Conv2D(32, 4, padding='same'))
    model.add(LeakyReLU(0.2))

    # Conv layer to get to three channels (RGB) and the desired output shape
    model.add(Conv2D(3, 4, padding='same', activation='sigmoid'))

    return model

# %%
generator = build_generator()

# %%
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 262144)            67371008
#
#  leaky_re_lu (LeakyReLU)     (None, 262144)            0
#
#  reshape (Reshape)           (None, 32, 32, 256)       0
#
#  up_sampling2d (UpSampling2D  (None, 64, 64, 256)      0
#  )
#
#  conv2d (Conv2D)             (None, 64, 64, 128)       819328
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 128)    0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 128)     409728
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 128)     0
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      131136
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)      32800
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 128, 128, 32)      0
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 3)       1539
#
# =================================================================
# Total params: 68,765,539
# Trainable params: 68,765,539
# Non-trainable params: 0
# _________________________________________________________________

# %%
imagee = generator.predict(np.random.randn(4,256))
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# Generate new paintings
generated_img = generator.predict(np.random.randn(4,256))

# Create a subplot with 1 row and 4 columns
fig, axs = plt.subplots(1, 4, figsize=(12, 3))

# Loop through the generated images and display them in the subplot
for i in range(4):
    axs[i].imshow(generated_img[i])
    axs[i].axis('off')

# Show the generated images in one row
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
generated_img.shape
# Out:
# (4, 128, 128, 3)

# %% [markdown]
# ### 3.3 Build Discriminator

# %%
def build_discriminator(): 
    model = Sequential()
    
    # First Conv Block
    model.add(Conv2D(32, 5, input_shape = (128,128,3)))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Second Conv Block
    model.add(Conv2D(64, 5))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Third Conv Block
    model.add(Conv2D(128, 5))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Fourth Conv Block
    model.add(Conv2D(256, 5))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.4))
    
    # Flatten then pass to dense layer
    model.add(Flatten())
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %%
discriminator = build_discriminator()

# %%
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 124, 124, 32)      2432
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 124, 124, 32)      0
#
#  dropout (Dropout)           (None, 124, 124, 32)      0
#
#  conv2d_6 (Conv2D)           (None, 120, 120, 64)      51264
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 120, 120, 64)      0
#
#  dropout_1 (Dropout)         (None, 120, 120, 64)      0
#
#  conv2d_7 (Conv2D)           (None, 116, 116, 128)     204928
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 116, 116, 128)     0
#
#  dropout_2 (Dropout)         (None, 116, 116, 128)     0
#
#  conv2d_8 (Conv2D)           (None, 112, 112, 256)     819456
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 112, 112, 256)     0
#
#  dropout_3 (Dropout)         (None, 112, 112, 256)     0
#
#  flatten (Flatten)           (None, 3211264)           0
#
#  dropout_4 (Dropout)         (None, 3211264)           0
#
#  dense_1 (Dense)             (None, 1)                 3211265
#
# =================================================================
# Total params: 4,289,345
# Trainable params: 4,289,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
imagee = generated_img[0]

# %%
imagee.shape
# Out:
# (128, 128, 3)

# %%
discriminator.predict(generated_img)
# Out:
# 1/1 [==============================] - 0s 322ms/step
# array([[0.5047712 ],
#        [0.50462645],
#        [0.5047978 ],
#        [0.5047834 ]], dtype=float32)

# %% [markdown]
# # 4. Construct Training Loop

# %% [markdown]
# ### 4.1 Setup Losses and Optimizers

# %%
# Adam is going to be the optimizer for both
from tensorflow.keras.optimizers import Adam
# Binary cross entropy is going to be the loss for both 
from tensorflow.keras.losses import BinaryCrossentropy

# %%
g_opt = Adam(learning_rate=0.0001) 
d_opt = Adam(learning_rate=0.00001) 
g_loss = BinaryCrossentropy()
d_loss = BinaryCrossentropy()

# %% [markdown]
# ### 4.2 Build Subclassed Model

# %%
# Importing the base model class to subclass our training step 
from tensorflow.keras.models import Model

# %%
class VanGoghGAN(Model): 
    def __init__(self, generator, discriminator, *args, **kwargs):
        # Pass through args and kwargs to base class 
        super().__init__(*args, **kwargs)
        
        # Create attributes for gen and disc
        self.generator = generator 
        self.discriminator = discriminator 
        
    def compile(self, g_opt, d_opt, g_loss, d_loss, *args, **kwargs): 
        # Compile with base class
        super().compile(*args, **kwargs)
        
        # Create attributes for losses and optimizers
        self.g_opt = g_opt
        self.d_opt = d_opt
        self.g_loss = g_loss
        self.d_loss = d_loss 

    def train_step(self, batch):
        # Get the data 
        real_images = batch
        fake_images = self.generator(tf.random.normal((32, 256)), training=False)
        
        # Train the discriminator
        with tf.GradientTape() as d_tape: 
            # Pass the real and fake images to the discriminator model
            yhat_real = self.discriminator(real_images, training=True) 
            yhat_fake = self.discriminator(fake_images, training=True)
            yhat_realfake = tf.concat([yhat_real, yhat_fake], axis=0)
            
            # Create labels for real and fakes images
            y_realfake = tf.concat([tf.zeros_like(yhat_real), tf.ones_like(yhat_fake)], axis=0)
            
            # Add some noise to the TRUE outputs
            noise_real = 0.15*tf.random.uniform(tf.shape(yhat_real))
            noise_fake = -0.15*tf.random.uniform(tf.shape(yhat_fake))
            y_realfake += tf.concat([noise_real, noise_fake], axis=0)
            
            # Calculate loss - BINARYCROSS 
            total_d_loss = self.d_loss(y_realfake, yhat_realfake)
            
        # Apply backpropagation - nn learn 
        dgrad = d_tape.gradient(total_d_loss, self.discriminator.trainable_variables) 
        self.d_opt.apply_gradients(zip(dgrad, self.discriminator.trainable_variables))
        
        # Train the generator 
        with tf.GradientTape() as g_tape: 
            # Generate some new images
            gen_images = self.generator(tf.random.normal((32, 256)), training=True)
                                        
            # Create the predicted labels
            predicted_labels = self.discriminator(gen_images, training=False)
                                        
            # Calculate loss - trick to training to fake out the discriminator
            total_g_loss = self.g_loss(tf.zeros_like(predicted_labels), predicted_labels) 
            
        # Apply backprop
        ggrad = g_tape.gradient(total_g_loss, self.generator.trainable_variables)
        self.g_opt.apply_gradients(zip(ggrad, self.generator.trainable_variables))
        
        return {"d_loss":total_d_loss, "g_loss":total_g_loss}

# %%
# Create instance of subclassed model
vangoghgan = VanGoghGAN(generator, discriminator)

# %%
# Compile the model
vangoghgan.compile(g_opt, d_opt, g_loss, d_loss)

# %% [markdown]
# ### 4.3 Build Callback

# %%
import os
from tensorflow.keras.preprocessing.image import array_to_img
from tensorflow.keras.callbacks import Callback

# %%
#Custom callback AN(3 images every 80 epochs)
class ModelMonitor(Callback):
    def __init__(self, num_img=3, latent_dim=256, save_interval=80):
        self.num_img = num_img
        self.latent_dim = latent_dim
        self.save_interval = save_interval

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.save_interval == 0:
            random_latent_vectors = tf.random.uniform((self.num_img, self.latent_dim, 1))
            generated_images = self.model.generator(random_latent_vectors)
            generated_images *= 255
            generated_images.numpy()
            for i in range(self.num_img):
                img = array_to_img(generated_images[i])
                img.save(os.path.join('gen_paintings_128x128', f'generated_img_epoch{epoch + 1}_{i}.jpg'))

# %% [markdown]
# ### 4.3 Train

# %%
# Recommend 2000 epochs
hist = vangoghgan.fit(ds, epochs=4000, callbacks=[ModelMonitor()])
# Out:
# Epoch 1/4000
# 5/5 [==============================] - 13s 737ms/step - d_loss: 0.6711 - g_loss: 0.8222
# Epoch 2/4000
# 5/5 [==============================] - 2s 478ms/step - d_loss: 0.6677 - g_loss: 0.7990
# Epoch 3/4000
# 5/5 [==============================] - 2s 477ms/step - d_loss: 0.6023 - g_loss: 0.6679
# Epoch 4/4000
# 5/5 [==============================] - 2s 479ms/step - d_loss: 0.6932 - g_loss: 0.5489
# Epoch 5/4000
# 5/5 [==============================] - 2s 480ms/step - d_loss: 0.8847 - g_loss: 0.5054
# Epoch 6/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.7214 - g_loss: 0.8024
# Epoch 7/4000
# 5/5 [==============================] - 2s 479ms/step - d_loss: 0.6959 - g_loss: 1.0282
# Epoch 8/4000
# 5/5 [==============================] - 2s 479ms/step - d_loss: 0.5518 - g_loss: 1.0095
# Epoch 9/4000
# 5/5 [==============================] - 2s 481ms/step - d_loss: 0.6266 - g_loss: 0.7020
# Epoch 10/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.8598 - g_loss: 0.3787
# Epoch 11/4000
# 5/5 [==============================] - 2s 481ms/step - d_loss: 0.7366 - g_loss: 0.6349
# Epoch 12/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.8274 - g_loss: 0.6541
# Epoch 13/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.8457 - g_loss: 0.5147
# Epoch 14/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.7152 - g_loss: 0.6424
# Epoch 15/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5342 - g_loss: 1.1489
# Epoch 16/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.4611 - g_loss: 1.5367
# Epoch 17/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.4950 - g_loss: 1.0762
# Epoch 18/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.7304 - g_loss: 0.4934
# Epoch 19/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.7014 - g_loss: 0.5337
# Epoch 20/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.7480 - g_loss: 0.6424
# Epoch 21/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.8065 - g_loss: 0.5008
# Epoch 22/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.7609 - g_loss: 0.4701
# Epoch 23/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6221 - g_loss: 0.5910
# Epoch 24/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.5356 - g_loss: 0.7399
# Epoch 25/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5893 - g_loss: 0.5727
# Epoch 26/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.6555 - g_loss: 0.4244
# Epoch 27/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6478 - g_loss: 0.5007
# Epoch 28/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.6396 - g_loss: 0.5393
# Epoch 29/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6379 - g_loss: 0.5411
# Epoch 30/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6073 - g_loss: 0.6674
# Epoch 31/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.6100 - g_loss: 0.7930
# Epoch 32/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.7194 - g_loss: 0.7727
# Epoch 33/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.9347 - g_loss: 0.5893
# Epoch 34/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 1.0815 - g_loss: 0.4952
# Epoch 35/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.9687 - g_loss: 0.5466
# Epoch 36/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.8069 - g_loss: 0.6149
# Epoch 37/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.7321 - g_loss: 0.6613
# Epoch 38/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6668 - g_loss: 0.7067
# Epoch 39/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.6186 - g_loss: 0.7319
# Epoch 40/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.5734 - g_loss: 0.7542
# Epoch 41/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5555 - g_loss: 0.7594
# Epoch 42/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5199 - g_loss: 0.7822
# Epoch 43/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5076 - g_loss: 0.8045
# Epoch 44/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.4934 - g_loss: 0.7962
# Epoch 45/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.4823 - g_loss: 0.8176
# Epoch 46/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.4963 - g_loss: 0.8136
# Epoch 47/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5028 - g_loss: 0.7818
# Epoch 48/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5221 - g_loss: 0.8014
# Epoch 49/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5267 - g_loss: 0.8173
# Epoch 50/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.4838 - g_loss: 0.8222
# Epoch 51/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5431 - g_loss: 0.8287
# Epoch 52/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5145 - g_loss: 0.8610
# Epoch 53/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.4942 - g_loss: 0.8938
# Epoch 54/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5413 - g_loss: 0.8384
# Epoch 55/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 1.0239 - g_loss: 0.5103
# Epoch 56/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.7481 - g_loss: 0.9334
# Epoch 57/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.8984 - g_loss: 0.4750
# Epoch 58/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.8172 - g_loss: 0.4166
# Epoch 59/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.8455 - g_loss: 0.3945
# Epoch 60/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.7693 - g_loss: 0.5471
# Epoch 61/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.7591 - g_loss: 0.6173
# Epoch 62/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.7179 - g_loss: 0.6320
# Epoch 63/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.6804 - g_loss: 0.7257
# Epoch 64/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.6435 - g_loss: 0.8903
# Epoch 65/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.6282 - g_loss: 1.0727
# Epoch 66/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6046 - g_loss: 1.2087
# Epoch 67/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.6072 - g_loss: 1.2532
# Epoch 68/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.6376 - g_loss: 1.0525
# Epoch 69/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.6059 - g_loss: 1.1668
# Epoch 70/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.5555 - g_loss: 1.3649
# Epoch 71/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.5649 - g_loss: 1.2255
# Epoch 72/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6375 - g_loss: 0.7317
# Epoch 73/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.6334 - g_loss: 0.6818
# Epoch 74/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.7353 - g_loss: 0.5480
# Epoch 75/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 1.1299 - g_loss: 0.3836
# Epoch 76/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.8165 - g_loss: 0.6059
# Epoch 77/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.6569 - g_loss: 0.8217
# Epoch 78/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.6178 - g_loss: 0.9697
# Epoch 79/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.5854 - g_loss: 1.0271
# Epoch 80/4000
# 5/5 [==============================] - 3s 571ms/step - d_loss: 0.5776 - g_loss: 1.0105
# Epoch 81/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.5524 - g_loss: 1.0486
# Epoch 82/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5294 - g_loss: 1.0918
# Epoch 83/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.5180 - g_loss: 1.1809
# Epoch 84/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.5086 - g_loss: 1.3092
# Epoch 85/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5201 - g_loss: 1.3572
# Epoch 86/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5488 - g_loss: 1.5098
# Epoch 87/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.6040 - g_loss: 1.3122
# Epoch 88/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.7435 - g_loss: 0.9680
# Epoch 89/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.7690 - g_loss: 1.3060
# Epoch 90/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.7629 - g_loss: 1.1992
# Epoch 91/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.7049 - g_loss: 1.0794
# Epoch 92/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.6382 - g_loss: 1.0506
# Epoch 93/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.5895 - g_loss: 1.1953
# Epoch 94/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5298 - g_loss: 1.4732
# Epoch 95/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5011 - g_loss: 1.4613
# Epoch 96/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.5490 - g_loss: 0.8318
# Epoch 97/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5298 - g_loss: 0.7448
# Epoch 98/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5033 - g_loss: 0.7397
# Epoch 99/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.4791 - g_loss: 0.7672
# Epoch 100/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.4680 - g_loss: 0.8068
# Epoch 101/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.4506 - g_loss: 0.8577
# Epoch 102/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.4279 - g_loss: 0.9174
# Epoch 103/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.4068 - g_loss: 0.9833
# Epoch 104/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.3943 - g_loss: 1.0597
# Epoch 105/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.3702 - g_loss: 1.1382
# Epoch 106/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.3691 - g_loss: 1.2006
# Epoch 107/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.3649 - g_loss: 1.2098
# Epoch 108/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.4099 - g_loss: 1.0952
# Epoch 109/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5138 - g_loss: 1.0077
# Epoch 110/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5808 - g_loss: 0.9862
# Epoch 111/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.5595 - g_loss: 0.9223
# Epoch 112/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5337 - g_loss: 0.8675
# Epoch 113/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.5069 - g_loss: 0.8714
# Epoch 114/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5397 - g_loss: 0.7907
# Epoch 115/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.5741 - g_loss: 0.6388
# Epoch 116/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5581 - g_loss: 0.9613
# Epoch 117/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.5227 - g_loss: 0.9752
# Epoch 118/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.5244 - g_loss: 1.5845
# Epoch 119/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.5195 - g_loss: 1.4044
# Epoch 120/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.4846 - g_loss: 1.4261
# Epoch 121/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.4779 - g_loss: 1.4566
# Epoch 122/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.4654 - g_loss: 1.3645
# Epoch 123/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.4521 - g_loss: 1.1893
# Epoch 124/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.4662 - g_loss: 1.0099
# Epoch 125/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.4856 - g_loss: 0.8108
# Epoch 126/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.4691 - g_loss: 0.8433
# Epoch 127/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.4706 - g_loss: 0.6265
# Epoch 128/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.4715 - g_loss: 0.5721
# Epoch 129/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.4633 - g_loss: 0.4516
# Epoch 130/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0
4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2696 - g_loss: 0.0013
# Epoch 192/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2796 - g_loss: 0.0010
# Epoch 193/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2777 - g_loss: 0.0011
# Epoch 194/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2845 - g_loss: 0.0011
# Epoch 195/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2784 - g_loss: 0.0011
# Epoch 196/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2703 - g_loss: 9.8405e-04
# Epoch 197/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2697 - g_loss: 0.0011
# Epoch 198/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2853 - g_loss: 8.7547e-04
# Epoch 199/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2745 - g_loss: 0.0011
# Epoch 200/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2746 - g_loss: 0.0010
# Epoch 201/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2874 - g_loss: 8.1384e-04
# Epoch 202/4000
# 5/5 [==============================] - 2s 490ms/step - d_loss: 0.2807 - g_loss: 0.0010
# Epoch 203/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2716 - g_loss: 8.1144e-04
# Epoch 204/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2751 - g_loss: 0.0011
# Epoch 205/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2705 - g_loss: 8.7194e-04
# Epoch 206/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.2785 - g_loss: 7.1381e-04
# Epoch 207/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2719 - g_loss: 9.3442e-04
# Epoch 208/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2732 - g_loss: 7.8833e-04
# Epoch 209/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2709 - g_loss: 8.2248e-04
# Epoch 210/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2742 - g_loss: 8.4798e-04
# Epoch 211/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2897 - g_loss: 7.9891e-04
# Epoch 212/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2795 - g_loss: 9.1781e-04
# Epoch 213/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2746 - g_loss: 7.6196e-04
# Epoch 214/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2620 - g_loss: 8.1839e-04
# Epoch 215/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2853 - g_loss: 7.6196e-04
# Epoch 216/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2812 - g_loss: 8.6078e-04
# Epoch 217/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2739 - g_loss: 7.2034e-04
# Epoch 218/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2813 - g_loss: 7.0508e-04
# Epoch 219/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2715 - g_loss: 8.5762e-04
# Epoch 220/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2808 - g_loss: 6.1074e-04
# Epoch 221/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2740 - g_loss: 8.7219e-04
# Epoch 222/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2642 - g_loss: 6.7994e-04
# Epoch 223/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2831 - g_loss: 7.4288e-04
# Epoch 224/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2921 - g_loss: 8.6864e-04
# Epoch 225/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2706 - g_loss: 6.5475e-04
# Epoch 226/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2776 - g_loss: 7.1138e-04
# Epoch 227/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2792 - g_loss: 6.8498e-04
# Epoch 228/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2690 - g_loss: 6.9692e-04
# Epoch 229/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2673 - g_loss: 7.0934e-04
# Epoch 230/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2747 - g_loss: 7.1190e-04
# Epoch 231/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2738 - g_loss: 6.9571e-04
# Epoch 232/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2657 - g_loss: 6.4902e-04
# Epoch 233/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2846 - g_loss: 6.6061e-04
# Epoch 234/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2710 - g_loss: 6.8710e-04
# Epoch 235/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2750 - g_loss: 6.9412e-04
# Epoch 236/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2699 - g_loss: 6.5684e-04
# Epoch 237/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2707 - g_loss: 6.9804e-04
# Epoch 238/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2754 - g_loss: 6.6464e-04
# Epoch 239/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2702 - g_loss: 6.2257e-04
# Epoch 240/4000
# 5/5 [==============================] - 2s 499ms/step - d_loss: 0.2683 - g_loss: 6.2318e-04
# Epoch 241/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2777 - g_loss: 6.2347e-04
# Epoch 242/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2829 - g_loss: 5.9948e-04
# Epoch 243/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2817 - g_loss: 6.4135e-04
# Epoch 244/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2701 - g_loss: 6.2838e-04
# Epoch 245/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2859 - g_loss: 6.8505e-04
# Epoch 246/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.
4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2862 - g_loss: 7.6122e-04
# Epoch 356/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2611 - g_loss: 8.1142e-04
# Epoch 357/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2741 - g_loss: 7.1995e-04
# Epoch 358/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2772 - g_loss: 7.9775e-04
# Epoch 359/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2686 - g_loss: 7.8499e-04
# Epoch 360/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2727 - g_loss: 7.8738e-04
# Epoch 361/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2640 - g_loss: 7.8338e-04
# Epoch 362/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2820 - g_loss: 7.3295e-04
# Epoch 363/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2704 - g_loss: 8.3562e-04
# Epoch 364/4000
# 5/5 [==============================] - 2s 490ms/step - d_loss: 0.2770 - g_loss: 7.3249e-04
# Epoch 365/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2680 - g_loss: 7.4113e-04
# Epoch 366/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2598 - g_loss: 7.8090e-04
# Epoch 367/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2679 - g_loss: 7.8065e-04
# Epoch 368/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2662 - g_loss: 6.6279e-04
# Epoch 369/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2705 - g_loss: 7.8329e-04
# Epoch 370/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2606 - g_loss: 8.4016e-04
# Epoch 371/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2738 - g_loss: 6.9803e-04
# Epoch 372/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2726 - g_loss: 8.2788e-04
# Epoch 373/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2738 - g_loss: 8.5420e-04
# Epoch 374/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2723 - g_loss: 6.6849e-04
# Epoch 375/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2750 - g_loss: 7.9585e-04
# Epoch 376/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2775 - g_loss: 7.7237e-04
# Epoch 377/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2623 - g_loss: 7.9374e-04
# Epoch 378/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2718 - g_loss: 7.4551e-04
# Epoch 379/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2633 - g_loss: 7.7147e-04
# Epoch 380/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2860 - g_loss: 7.5354e-04
# Epoch 381/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2809 - g_loss: 7.6764e-04
# Epoch 382/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2754 - g_loss: 7.5504e-04
# Epoch 383/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2638 - g_loss: 6.9977e-04
# Epoch 384/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2801 - g_loss: 7.5425e-04
# Epoch 385/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2766 - g_loss: 8.0327e-04
# Epoch 386/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2685 - g_loss: 7.4254e-04
# Epoch 387/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2877 - g_loss: 7.9656e-04
# Epoch 388/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2610 - g_loss: 9.4565e-04
# Epoch 389/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2703 - g_loss: 7.0865e-04
# Epoch 390/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2641 - g_loss: 8.1837e-04
# Epoch 391/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2633 - g_loss: 8.7299e-04
# Epoch 392/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2734 - g_loss: 7.4085e-04
# Epoch 393/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2761 - g_loss: 7.9890e-04
# Epoch 394/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2631 - g_loss: 8.0159e-04
# Epoch 395/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2655 - g_loss: 7.9710e-04
# Epoch 396/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2693 - g_loss: 7.8648e-04
# Epoch 397/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2733 - g_loss: 7.5064e-04
# Epoch 398/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2578 - g_loss: 9.2744e-04
# Epoch 399/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2683 - g_loss: 7.6674e-04
# Epoch 400/4000
# 5/5 [==============================] - 2s 496ms/step - d_loss: 0.2788 - g_loss: 8.0315e-04
# Epoch 401/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2702 - g_loss: 8.1080e-04
# Epoch 402/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2703 - g_loss: 7.5550e-04
# Epoch 403/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2792 - g_loss: 7.6770e-04
# Epoch 404/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2674 - g_loss: 8.3317e-04
# Epoch 405/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2692 - g_loss: 8.0671e-04
# Epoch 406/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2764 - g_loss: 7.7339e-04
# Epoch 407/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2757 - g_loss: 9.3874e-04
# Epoch 408/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2659 - g_loss: 7.8901e-04
# Epoch 409/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2722 - g_loss: 9.4910e-04
# Epoch 410/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2719 - g_loss: 8.3910e-04
# Epoch 411/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2686 - g_loss: 7.4982e-04
# Epoch 412/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2704 - g_loss: 8.5047e-04
# Epoch 413/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2660 - g_loss: 7.2453e-04
# Epoch 414/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2654 - g_loss: 8.2712e-04
# Epoch 415/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2696 - g_loss: 8.7219e-04
# Epoch 416/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2704 - g_loss: 8.4061e-04
# Epoch 417/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2790 - g_loss: 7.6681e-04
# Epoch 418/4000
# 5/5 [==============================] - 2s 483ms/step - d_loss: 0.2813 - g_loss: 8.9356e-04
# Epoch 419/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2812 - g_loss: 7.4399e-04
# Epoch 420/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2746 - g_loss: 8.2775e-04
# Epoch 421/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2654 - g_loss: 8.7081e-04
# Epoch 422/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.2734 - g_loss: 7.6522e-04
# Epoch 423/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2657 - g_loss: 8.9385e-04
# Epoch 424/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2667 - g_loss: 8.4742e-04
# Epoch 425/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2655 - g_loss: 8.8517e-04
# Epoch 426/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2750 - g_loss: 9.0276e-04
# Epoch 427/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2794 - g_loss: 7.8908e-04
# Epoch 428/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2807 - g_loss: 8.6176e-04
# Epoch 429/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2736 - g_loss: 8.8824e-04
# Epoch 430/4000
# 5/5 [==============================] - 2s 490ms/step - d_loss: 0.2653 - g_loss: 8.5613e-04
# Epoch 431/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2659 - g_loss: 9.4631e-04
# Epoch 432/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2693 - g_loss: 8.0173e-04
# Epoch 433/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2791 - g_loss: 8.5102e-04
# Epoch 434/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2722 - g_loss: 8.4450e-04
# Epoch 435/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2776 - g_loss: 7.8507e-04
# Epoch 436/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2726 - g_loss: 9.6854e-04
# Epoch 437/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2728 - g_loss: 7.6914e-04
# Epoch 438/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2782 - g_loss: 8.8750e-04
# Epoch 439/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2711 - g_loss: 8.3921e-04
# Epoch 440/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2793 - g_loss: 8.2592e-04
# Epoch 441/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2667 - g_loss: 8.2556e-04
# Epoch 442/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2665 - g_loss: 8.5322e-04
# Epoch 443/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2682 - g_loss: 8.2265e-04
# Epoch 444/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2746 - g_loss: 8.3606e-04
# Epoch 445/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2772 - g_loss: 0.0010
# Epoch 446/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2845 - g_loss: 7.4345e-04
# Epoch 447/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2583 - g_loss: 0.0011
# Epoch 448/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2769 - g_loss: 9.0466e-04
# Epoch 449/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2713 - g_loss: 8.8888e-04
# Epoch 450/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2688 - g_loss: 8.9384e-04
# Epoch 451/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2762 - g_loss: 9.5316e-04
# Epoch 452/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2732 - g_loss: 8.3522e-04
# Epoch 453/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2631 - g_loss: 0.0010
# Epoch 454/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2699 - g_loss: 9.5166e-04
# Epoch 455/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2750 - g_loss: 9.7527e-04
# Epoch 456/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2682 - g_loss: 9.3837e-04
# Epoch 457/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2794 - g_loss: 8.6295e-04
# Epoch 458/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2686 - g_loss: 9.4357e-04
# Epoch 459/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2834 - g_loss: 8.5956e-04
# Epoch 460/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2697 - g_loss: 8.6168e-04
# Epoch 461/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2723 - g_loss: 9.5111e-04
# Epoch 462/4000
# ...
# Epoch 3848/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2752 - g_loss: 9.6176e-04
# Epoch 3849/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2506 - g_loss: 0.0011
# Epoch 3850/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2554 - g_loss: 9.8214e-04
# Epoch 3851/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2711 - g_loss: 9.6931e-04
# Epoch 3852/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2632 - g_loss: 9.3616e-04
# Epoch 3853/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2605 - g_loss: 9.9327e-04
# Epoch 3854/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2702 - g_loss: 9.6202e-04
# Epoch 3855/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2679 - g_loss: 0.0010
# Epoch 3856/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2663 - g_loss: 0.0010
# Epoch 3857/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2566 - g_loss: 0.0010
# Epoch 3858/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2644 - g_loss: 0.0010
# Epoch 3859/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2651 - g_loss: 9.7249e-04
# Epoch 3860/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2614 - g_loss: 0.0011
# Epoch 3861/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2699 - g_loss: 9.3535e-04
# Epoch 3862/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2721 - g_loss: 0.0011
# Epoch 3863/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2643 - g_loss: 9.6730e-04
# Epoch 3864/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2677 - g_loss: 0.0011
# Epoch 3865/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2637 - g_loss: 9.7497e-04
# Epoch 3866/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2696 - g_loss: 0.0011
# Epoch 3867/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2751 - g_loss: 9.7816e-04
# Epoch 3868/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2693 - g_loss: 0.0012
# Epoch 3869/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.2704 - g_loss: 9.7544e-04
# Epoch 3870/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2615 - g_loss: 0.0011
# Epoch 3871/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2670 - g_loss: 9.4244e-04
# Epoch 3872/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2724 - g_loss: 0.0011
# Epoch 3873/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2648 - g_loss: 9.6853e-04
# Epoch 3874/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2643 - g_loss: 0.0011
# Epoch 3875/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2725 - g_loss: 0.0010
# Epoch 3876/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2794 - g_loss: 0.0012
# Epoch 3877/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2688 - g_loss: 9.9463e-04
# Epoch 3878/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2691 - g_loss: 0.0012
# Epoch 3879/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2647 - g_loss: 0.0011
# Epoch 3880/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2668 - g_loss: 0.0011
# Epoch 3881/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2608 - g_loss: 0.0011
# Epoch 3882/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2600 - g_loss: 0.0011
# Epoch 3883/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2761 - g_loss: 0.0011
# Epoch 3884/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2589 - g_loss: 0.0010
# Epoch 3885/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2635 - g_loss: 0.0012
# Epoch 3886/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2674 - g_loss: 0.0010
# Epoch 3887/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2716 - g_loss: 0.0011
# Epoch 3888/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2722 - g_loss: 0.0011
# Epoch 3889/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2796 - g_loss: 0.0011
# Epoch 3890/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2689 - g_loss: 0.0012
# Epoch 3891/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2624 - g_loss: 0.0012
# Epoch 3892/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2762 - g_loss: 0.0011
# Epoch 3893/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2649 - g_loss: 0.0012
# Epoch 3894/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2636 - g_loss: 0.0011
# Epoch 3895/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2820 - g_loss: 0.0011
# Epoch 3896/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2621 - g_loss: 0.0011
# Epoch 3897/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2608 - g_loss: 0.0011
# Epoch 3898/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.2546 - g_loss: 0.0010
# Epoch 3899/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2696 - g_loss: 0.0011
# Epoch 3900/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2750 - g_loss: 0.0010
# Epoch 3901/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2775 - g_loss: 0.0011
# Epoch 3902/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2599 - g_loss: 0.0010
# Epoch 3903/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2742 - g_loss: 0.0011
# Epoch 3904/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.2703 - g_loss: 0.0011
# Epoch 3905/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2671 - g_loss: 0.0010
# Epoch 3906/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2566 - g_loss: 0.0011
# Epoch 3907/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2649 - g_loss: 0.0011
# Epoch 3908/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2733 - g_loss: 0.0010
# Epoch 3909/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2741 - g_loss: 0.0011
# Epoch 3910/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2667 - g_loss: 0.0011
# Epoch 3911/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2665 - g_loss: 0.0011
# Epoch 3912/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2733 - g_loss: 0.0010
# Epoch 3913/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2591 - g_loss: 0.0011
# Epoch 3914/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2770 - g_loss: 0.0011
# Epoch 3915/4000
# 5/5 [==============================] - 2s 490ms/step - d_loss: 0.2668 - g_loss: 0.0010
# Epoch 3916/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2557 - g_loss: 0.0011
# Epoch 3917/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2631 - g_loss: 9.9813e-04
# Epoch 3918/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2640 - g_loss: 9.9326e-04
# Epoch 3919/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2790 - g_loss: 9.8138e-04
# Epoch 3920/4000
# 5/5 [==============================] - 2s 492ms/step - d_loss: 0.2655 - g_loss: 0.0010
# Epoch 3921/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2721 - g_loss: 0.0011
# Epoch 3922/4000
# 5/5 [==============================] - 2s 489ms/step - d_loss: 0.2784 - g_loss: 0.0010
# Epoch 3923/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2734 - g_loss: 0.0011
# Epoch 3924/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2627 - g_loss: 0.0012
# Epoch 3925/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2702 - g_loss: 0.0011
# Epoch 3926/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2725 - g_loss: 0.0011
# Epoch 3927/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2697 - g_loss: 9.6625e-04
# Epoch 3928/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2689 - g_loss: 0.0011
# Epoch 3929/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2676 - g_loss: 9.4143e-04
# Epoch 3930/4000
# 5/5 [==============================] - 2s 491ms/step - d_loss: 0.2682 - g_loss: 0.0011
# Epoch 3931/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2732 - g_loss: 9.8736e-04
# Epoch 3932/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2606 - g_loss: 0.0011
# Epoch 3933/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2692 - g_loss: 0.0011
# Epoch 3934/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2748 - g_loss: 0.0011
# Epoch 3935/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2703 - g_loss: 0.0011
# Epoch 3936/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2642 - g_loss: 0.0011
# Epoch 3937/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2645 - g_loss: 0.0012
# Epoch 3938/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2701 - g_loss: 0.0011
# Epoch 3939/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2742 - g_loss: 0.0011
# Epoch 3940/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2704 - g_loss: 0.0011
# Epoch 3941/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2746 - g_loss: 0.0011
# Epoch 3942/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2714 - g_loss: 0.0011
# Epoch 3943/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2617 - g_loss: 0.0011
# Epoch 3944/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2677 - g_loss: 0.0010
# Epoch 3945/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2603 - g_loss: 0.0011
# Epoch 3946/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2606 - g_loss: 0.0010
# Epoch 3947/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2659 - g_loss: 0.0010
# Epoch 3948/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2665 - g_loss: 9.9567e-04
# Epoch 3949/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2548 - g_loss: 0.0011
# Epoch 3950/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2709 - g_loss: 9.8155e-04
# Epoch 3951/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2695 - g_loss: 0.0010
# Epoch 3952/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2722 - g_loss: 0.0010
# Epoch 3953/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2746 - g_loss: 0.0010
# Epoch 3954/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2677 - g_loss: 0.0011
# Epoch 3955/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2694 - g_loss: 0.0011
# Epoch 3956/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2649 - g_loss: 0.0010
# Epoch 3957/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2671 - g_loss: 0.0010
# Epoch 3958/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2774 - g_loss: 9.7137e-04
# Epoch 3959/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2822 - g_loss: 9.6886e-04
# Epoch 3960/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2749 - g_loss: 9.8893e-04
# Epoch 3961/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2653 - g_loss: 0.0010
# Epoch 3962/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2664 - g_loss: 0.0010
# Epoch 3963/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2602 - g_loss: 0.0010
# Epoch 3964/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2696 - g_loss: 0.0010
# Epoch 3965/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2634 - g_loss: 0.0010
# Epoch 3966/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2721 - g_loss: 0.0010
# Epoch 3967/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2704 - g_loss: 0.0010
# Epoch 3968/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2576 - g_loss: 0.0010
# Epoch 3969/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2683 - g_loss: 9.4644e-04
# Epoch 3970/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2639 - g_loss: 0.0010
# Epoch 3971/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2639 - g_loss: 9.5984e-04
# Epoch 3972/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2759 - g_loss: 9.9665e-04
# Epoch 3973/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2711 - g_loss: 9.7472e-04
# Epoch 3974/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2760 - g_loss: 9.9279e-04
# Epoch 3975/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2628 - g_loss: 9.8215e-04
# Epoch 3976/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2708 - g_loss: 9.7192e-04
# Epoch 3977/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2646 - g_loss: 0.0010
# Epoch 3978/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2750 - g_loss: 9.4298e-04
# Epoch 3979/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2832 - g_loss: 0.0010
# Epoch 3980/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2713 - g_loss: 9.6772e-04
# Epoch 3981/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2677 - g_loss: 0.0010
# Epoch 3982/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2661 - g_loss: 0.0010
# Epoch 3983/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2574 - g_loss: 0.0010
# Epoch 3984/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2575 - g_loss: 0.0010
# Epoch 3985/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2791 - g_loss: 9.2278e-04
# Epoch 3986/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2690 - g_loss: 9.8394e-04
# Epoch 3987/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2589 - g_loss: 9.9758e-04
# Epoch 3988/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2675 - g_loss: 9.8755e-04
# Epoch 3989/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2619 - g_loss: 9.4699e-04
# Epoch 3990/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2793 - g_loss: 0.0010
# Epoch 3991/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2746 - g_loss: 9.5700e-04
# Epoch 3992/4000
# 5/5 [==============================] - 2s 488ms/step - d_loss: 0.2688 - g_loss: 0.0012
# Epoch 3993/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2752 - g_loss: 0.0010
# Epoch 3994/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2735 - g_loss: 0.0012
# Epoch 3995/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2668 - g_loss: 0.0013
# Epoch 3996/4000
# 5/5 [==============================] - 2s 485ms/step - d_loss: 0.2890 - g_loss: 0.0012
# Epoch 3997/4000
# 5/5 [==============================] - 2s 487ms/step - d_loss: 0.2697 - g_loss: 0.0012
# Epoch 3998/4000
# 5/5 [==============================] - 2s 486ms/step - d_loss: 0.2545 - g_loss: 0.0012
# Epoch 3999/4000
# 5/5 [==============================] - 2s 484ms/step - d_loss: 0.2731 - g_loss: 0.0011
# Epoch 4000/4000
# 5/5 [==============================] - 2s 493ms/step - d_loss: 0.2694 - g_loss: 0.0011

# %% [markdown]
# ### 4.4 Review Performance

# %%
plt.suptitle('Loss')
plt.plot(hist.history['d_loss'], label='d_loss')
plt.plot(hist.history['g_loss'], label='g_loss')
plt.legend()
plt.show()

# %% [markdown]
# # 5. Test Out the Generator

# %% [markdown]
# ### 5.1 Generate Images

# %%
#generator.load_weights(os.path.join('archive', 'generatormodel.h5'))

# %%
imgs = generator.predict(tf.random.normal((16, 256)))
# Out:
# 1/1 [==============================] - 1s 682ms/step

# %%
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(10,10))
for r in range(4): 
    for c in range(4): 
        ax[r][c].imshow(imgs[(r+1)*(c+1)-1])
plt.show()

# %% [markdown]
# ### 5.2 Save the Model

# %%
generator.save('generator.h5')
discriminator.save('discriminator.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
